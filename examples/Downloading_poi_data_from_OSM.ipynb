# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nomad.maps as nmp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nomad.maps as nmp
#
# File ~\Desktop\Brain\Code Development\nomad\nomad\maps.py:14
#      12 import numpy as np
#      13 import pandas as pd
# ---> 14 import osmnx as ox
#      15 from nomad.map_constants import (
#      16     LOCATION_TYPE_MAPPING, BUILDING_CATEGORIES, BUSINESS_CLASSIFICATIONS,
#      17     DEFAULT_CRS
#      18 )
#      21 class OSMDataDownloader:
#
# ModuleNotFoundError: No module named 'osmnx'

# %% [markdown]
# linked

# %%
# Download buildings with garden_city categorization
buildings = download_osm_buildings(bbox, schema='garden_city')

print(f"Downloaded {len(buildings)} buildings")
print(f"\nBuilding categories:")
print(buildings['category'].value_counts())

# %%
# Download street network
streets = download_osm_streets(bbox)

print(f"Downloaded {len(streets)} street segments")

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# Buildings by category
ax1 = axes[0]
buildings.plot(ax=ax1, column='category', legend=True, 
               cmap='tab10', edgecolor='black', linewidth=0.5)
ax1.set_title('Buildings by Category')

# Streets and buildings
ax2 = axes[1]
buildings.plot(ax=ax2, color='lightgray', edgecolor='black', linewidth=0.5, alpha=0.7)
streets.plot(ax=ax2, color='navy', linewidth=1.5, alpha=0.8)
ax2.set_title('Streets and Buildings')

plt.tight_layout()
plt.show()

# %%
# Rotate by 10 degrees
rotation_angle = 10

buildings_rotated = rotate_and_explode(buildings, rotation_deg=rotation_angle)
streets_rotated = rotate_and_explode(streets, rotation_deg=rotation_angle)

# Visualize
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

ax1 = axes[0]
buildings.plot(ax=ax1, color='lightgray', edgecolor='black', linewidth=0.5, alpha=0.7)
streets.plot(ax=ax1, color='navy', linewidth=1.5, alpha=0.8)
ax1.set_title('Original')

ax2 = axes[1]
buildings_rotated.plot(ax=ax2, color='lightgray', edgecolor='black', linewidth=0.5, alpha=0.7)
streets_rotated.plot(ax=ax2, color='navy', linewidth=1.5, alpha=0.8)
ax2.set_title(f'Rotated {rotation_angle}°')

plt.tight_layout()
plt.show()
