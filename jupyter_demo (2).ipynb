# %%
# !pip install wattslab-atlas
# !pip install --upgrade wattslab-atlas
# Out:
# Collecting wattslab-atlas
#   Downloading wattslab_atlas-1.2.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.32.4)
# Collecting types-requests>=2.31.0 (from wattslab-atlas)
#   Downloading types_requests-2.32.4.20250913-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.11.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.9.0.post0)
# Requirement already satisfied: keyring>=24.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (25.6.0)
# Requirement already satisfied: cryptography>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (43.0.3)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (6.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=41.0.0->wattslab-atlas) (2.0.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (6.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->wattslab-atlas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (2025.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=41.0.0->wattslab-atlas) (2.23)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=24.0.0->wattslab-atlas) (10.8.0)
# Downloading wattslab_atlas-1.2.0-py3-none-any.whl (13 kB)
# Downloading types_requests-2.32.4.20250913-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, wattslab-atlas
# Successfully installed types-requests-2.32.4.20250913 wattslab-atlas-1.2.0
# Requirement already satisfied: wattslab-atlas in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.32.4)
# Requirement already satisfied: types-requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.32.4.20250913)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.11.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (2.9.0.post0)
# Requirement already satisfied: keyring>=24.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (25.6.0)
# Requirement already satisfied: cryptography>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (43.0.3)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from wattslab-atlas) (6.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=41.0.0->wattslab-atlas) (2.0.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=24.0.0->wattslab-atlas) (6.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->wattslab-atlas) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->wattslab-atlas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->wattslab-atlas) (2025.8.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=41.0.0->wattslab-atlas) (2.23)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=24.0.0->wattslab-atlas) (10.8.0)

# %%
"""
# Atlas SDK - Jupyter Demo

This notebook shows how to use the Atlas SDK in Jupyter.
"""

from wattslab_atlas import AtlasClient
from wattslab_atlas.models import FeatureCreate

# %%
# Initialize client
client = AtlasClient()


# Login - will reuse saved credentials if available
client.login("caroltu@seas.upenn.edu")
# Out:
# Atlas SDK version: 1.2.0
# {'message': 'SDK token sent. Check your email.'}

# %%
# If you received a magic link, validate it here
# comment out if not needed
client.validate_magic_link(input("Enter the token you received in your email: ").strip())
# Out:
# Enter the token you received in your email: ZQ9VCPAJnCFG5ni97O89KnGYZl_pSbEy4xjobDe9wNFpF-gSGtvNSbo4g6mF8LMU6HQqA96nIVl_UcLQE0C4bQ
# {'message': 'Magic link validated.',
#  'email': 'caroltu@seas.upenn.edu',
#  'credits': 5000}

# %%
# List features
features = client.list_features()
print(f"Found {len(features)} features\n")

# Display in a nice format
for f in features[:5]:
    print(f"{f.feature_name}")
    print(f"   {f.feature_description}")
    print(f"   Type: {f.feature_type} | ID: {f.id[:8]}...")
    print()
# Out:
# Found 105 features
#
# 📋 paper
#    features of a paper.
#    Type: array | ID: 67531047...
#
# 📋 title
#    The title of the paper.
#    Type: string | ID: 67531047...
#
# 📋 experiments
#    The experiments in a paper.
#    Type: array | ID: 67531048...
#
# 📋 name
#    The name of the experiments in the study.
#    Type: string | ID: 67531048...
#
# 📋 description
#    Description of the found experiment.
#    Type: string | ID: 67531048...

# %%
# List your papers
papers = client.list_papers(page=1, page_size=5)
print(f"Total papers: {papers.total_papers}\n")

for p in papers.papers:
    print(f"{p.title or p.file_name} (ID: {p.id[:8]}...)")
# Out:
# Total papers: 6
#
# 📄 nomad.pdf (ID: 68cd9fd7...)
# 📄 96227087-47db-43be-862e-99e0a0f1c6fa.pdf (ID: 68d2d598...)
# 📄 Analyzing_large_scale_human_mobility_dat.pdf (ID: 68d2d5db...)
# 📄 3106774.pdf (ID: 68d2e238...)
# 📄 Conduct an Ethnographic Interview.pdf (ID: 68daf28a...)

# %%
projects = client.list_projects()
for project in projects:
    print(f"{project.title}: {len(project.papers)} papers")

# Get specific project results
project_id = "68a8661d599246127d859169"
results = client.get_project_results(project_id)

# Process results
for result in results["results"]:
    paper_id = result.get("_paper_id")
    version = result.get("_version", 1)
    # Access extracted features from the result
    for key, value in result.items():
        if not key.startswith("_"):  # Skip metadata fields
            print(f"{key}: {value}")
# Out:
# testproject: 4 papers
# paper: [{'title': 'Temporal understanding of human mobility: A multi-time scale analysis', 'data_sample': [{'dataset_type': 'mobility', 'provider_name': 'carrier', 'filters': [{'filter_type': 'geographical', 'filter_expression': '("city","==","Xi\'an")', 'filter_key': 'city'}, {'filter_type': 'temporal', 'filter_expression': '("duration","==","1 week")', 'filter_key': 'duration'}], 'completeness_statistic': [{'completeness_statistic_name': 'sampling rate', 'completeness_statistic_value': 'mean,188s'}]}, {'dataset_type': 'mobility', 'provider_name': 'carrier', 'filters': [{'filter_type': 'geographical', 'filter_expression': '("city","==","Shenyang")', 'filter_key': 'city'}, {'filter_type': 'temporal', 'filter_expression': '("duration","==","5 weeks")', 'filter_key': 'duration'}], 'completeness_statistic': []}, {'dataset_type': 'mobility', 'provider_name': 'carrier', 'filters': [{'filter_type': 'geographical', 'filter_expression': '("city","==","Urumqi")', 'filter_key': 'city'}, {'filter_type': 'temporal', 'filter_expression': '("duration","==","1 month")', 'filter_key': 'duration'}], 'completeness_statistic': [{'completeness_statistic_name': 'sampling rate', 'completeness_statistic_value': 'mean,12h'}]}], 'experiments': [{'domain': 'data validation', 'code_location': '', 'description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.', 'mobility_metric': [{'temporal_aggregation': 'day', 'spatial_aggregation': 'cell_tower', 'metric_name': 'daily number of records', 'processing_step': [{'name': 'count', 'type': 'aggregation'}]}, {'temporal_aggregation': 'event', 'spatial_aggregation': 'cell_tower', 'metric_name': 'interevent time distribution', 'processing_step': [{'name': 'compute interevent time', 'type': 'noise removal'}]}, {'temporal_aggregation': 'event', 'spatial_aggregation': 'cell_tower', 'metric_name': 'interevent distance distribution', 'processing_step': [{'name': 'compute interevent distance', 'type': 'noise removal'}]}]}, {'domain': 'model fitting', 'code_location': '', 'description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.', 'mobility_metric': [{'temporal_aggregation': 'sampling_interval', 'spatial_aggregation': 'cell_tower', 'metric_name': 'displacement', 'processing_step': [{'name': 'resampling', 'type': 'aggregation'}, {'name': 'maximum likelihood fitting', 'type': 'model fitting'}]}, {'temporal_aggregation': 'full_trajectory', 'spatial_aggregation': 'cell_tower', 'metric_name': 'radius of gyration', 'processing_step': [{'name': 'compute gyration radius', 'type': 'aggregation'}]}, {'temporal_aggregation': 'sampling_interval', 'spatial_aggregation': 'cell_tower', 'metric_name': 'waiting time', 'processing_step': [{'name': 'resampling', 'type': 'aggregation'}, {'name': 'power-law fitting', 'type': 'model fitting'}]}, {'temporal_aggregation': 'sampling_interval', 'spatial_aggregation': 'cell_tower', 'metric_name': 'moving speed', 'processing_step': [{'name': 'resampling', 'type': 'aggregation'}, {'name': 'compute speed distribution', 'type': 'model fitting'}]}]}]}]
# created_at: 2025-09-08 14:44:00
# paper: [{'title': 'The scales of human mobility', 'data_sample': [{'dataset_type': 'mobility', 'provider_name': 'globalcompany', 'filters': [{'filter_type': 'temporal', 'filter_expression': '("date_range","between","2017-2019")', 'filter_key': 'date range'}, {'filter_type': 'completeness', 'filter_expression': '("time_coverage","ge","50% per day")', 'filter_key': 'completeness rate'}, {'filter_type': 'completeness', 'filter_expression': '("days_of_data","ge","365 days")', 'filter_key': 'days with activity'}], 'completeness_statistic': [{'completeness_statistic_name': 'completeness rate', 'completeness_statistic_value': 'average 50% per day'}, {'completeness_statistic_name': 'days with activity', 'completeness_statistic_value': '>=365 days'}]}, {'dataset_type': 'mobility', 'provider_name': 'direct_collection', 'filters': [{'filter_type': 'temporal', 'filter_expression': '("date_range","between","Sep2013-Sep2015")', 'filter_key': 'date range'}, {'filter_type': 'noise removal', 'filter_expression': '("location_error","le","50 m")', 'filter_key': 'location estimation error'}], 'completeness_statistic': [{'completeness_statistic_name': 'sampling rate', 'completeness_statistic_value': '1–2 min interval'}]}], 'experiments': [{'domain': 'model fitting', 'code_location': 'https://github.com/lalessan/scales_human_mobility/', 'description': 'Fitting the container model to individual GPS traces (datasets D1 and D2) using maximum likelihood estimation to infer a hierarchical structure of spatial containers and their attractiveness for each user.', 'mobility_metric': [{'temporal_aggregation': 'per trajectory', 'spatial_aggregation': 'container level', 'metric_name': 'container size', 'processing_step': [{'name': 'Infostop algorithm', 'type': 'stop detection'}, {'name': 'complete linkage clustering', 'type': 'aggregation weights'}, {'name': 'maximum likelihood estimation', 'type': 'algorithm fitting'}]}, {'temporal_aggregation': 'per trajectory', 'spatial_aggregation': 'container level', 'metric_name': 'time in container', 'processing_step': [{'name': 'Infostop algorithm', 'type': 'stop detection'}, {'name': 'lognormal fit', 'type': 'filtering'}]}]}, {'domain': 'data generation', 'code_location': 'https://github.com/lalessan/scales_human_mobility/', 'description': 'Generating synthetic mobility traces by simulating agents transitioning between hierarchical containers using learned attractiveness and level-distance probabilities to assess the realistic reproduction of trajectory statistics.', 'mobility_metric': [{'temporal_aggregation': 'displacement-based', 'spatial_aggregation': 'individual location', 'metric_name': 'displacement length distribution', 'processing_step': [{'name': 'trajectory simulation', 'type': 'aggregation weights'}]}, {'temporal_aggregation': 'over number of displacements', 'spatial_aggregation': 'individual location', 'metric_name': 'radius of gyration', 'processing_step': [{'name': 'distance calculation', 'type': 'aggregation weights'}]}, {'temporal_aggregation': 'per trajectory', 'spatial_aggregation': 'individual location', 'metric_name': 'location frequency distribution', 'processing_step': [{'name': 'frequency counting', 'type': 'filtering'}]}, {'temporal_aggregation': 'per trajectory', 'spatial_aggregation': 'individual location', 'metric_name': 'entropy difference', 'processing_step': [{'name': 'uncorrelated entropy estimation', 'type': 'aggregation weights'}, {'name': 'temporal entropy estimation', 'type': 'aggregation weights'}]}]}, {'domain': 'algorithm validation', 'code_location': '', 'description': 'Comparing synthetic traces generated by the container model with real traces and state-of-the-art models (EPR and its variants) using likelihood ratio tests and key trajectory metrics to validate the container model’s performance.', 'mobility_metric': [{'temporal_aggregation': 'displacement-based', 'spatial_aggregation': 'individual location', 'metric_name': 'displacement length distribution', 'processing_step': ...
# created_at: 2025-09-08 15:32:58
# paper: [{'title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data', 'data_sample': [{'dataset_type': 'mobility', 'provider_name': 'direct collection', 'filters': [], 'completeness_statistic': []}, {'dataset_type': 'geometry', 'provider_name': 'direct collection', 'filters': [], 'completeness_statistic': []}], 'experiments': [{'domain': 'data generation', 'code_location': 'https://github.com/Watts-Lab/nomad/', 'description': 'Generation of synthetic human mobility dataset using an agent-based model including synthetic city, EPR mobility diary, Brownian motion micro-dynamics, and self-exciting point process for sparse trajectory sampling.', 'mobility_metric': []}, {'domain': 'algorithm validation', 'code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city', 'description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.', 'mobility_metric': [{'temporal_aggregation': 'trip-level', 'spatial_aggregation': 'building-level', 'metric_name': 'visits to POI', 'processing_step': [{'name': 'self-exciting point process', 'type': 'filtering'}, {'name': 'Gaussian spatial noise', 'type': 'filtering'}, {'name': 'DBScan', 'type': 'stop detection'}]}]}, {'domain': 'algorithm validation', 'code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city', 'description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.', 'mobility_metric': [{'temporal_aggregation': 'session-level', 'spatial_aggregation': 'building-level', 'metric_name': 'stop duration', 'processing_step': [{'name': 'Brownian motion micro-dynamics', 'type': 'filtering'}, {'name': 'Gaussian spatial noise', 'type': 'filtering'}, {'name': 'Project Lachesis', 'type': 'stop detection'}]}]}]}]
# created_at: 2025-09-19 18:24:23

# %%
def flatten_object(obj, paths_to_collapse=None, current_path=""):
    if paths_to_collapse is None:
        paths_to_collapse = []

    def join_path(p, k):
        return f"{p}.{k}" if p else k

    def prefix_keys(row, prefix):
        """Prefix every key of `row` with `prefix`"""
        return {f"{prefix} {k}": v for k, v in row.items()}

    if isinstance(obj, list):
        result = []
        for item in obj:
            result.extend(flatten_object(item, paths_to_collapse, current_path))
        return result

    rows = [{}]  # start with one empty row

    for key, value in obj.items():
        full_path = join_path(current_path, key)

        if isinstance(value, list):
            if full_path in paths_to_collapse:
                # collapse ⇒ one cell with the count
                for r in rows:
                    r[key] = f"{len(value)} {key}"
            else:
                # expand ⇒ one row per element
                if len(value) == 0:
                    child_rows = [{}]
                else:
                    child_rows = []
                    for elem in value:
                        child_rows.extend(flatten_object(elem, paths_to_collapse, full_path))

                new_rows = []
                for r in rows:
                    for cr in child_rows:
                        new_rows.append({**r, **prefix_keys(cr, key)})
                rows = new_rows
            continue

        if isinstance(value, dict):
            child_rows = flatten_object(value, paths_to_collapse, full_path)
            new_rows = []
            for r in rows:
                for cr in child_rows:
                    new_rows.append({**r, **prefix_keys(cr, key)})
            rows = new_rows
            continue

        for r in rows:
            r[key] = value

    return rows


def nest_flat_keys(flat_obj):
    nested = {}

    for key, val in flat_obj.items():
        segments = key.split(" ")
        curr = nested

        for i, segment in enumerate(segments):
            # Remove "_truth" suffix if present
            if segment.endswith("_truth"):
                segment = segment[:-6]

            if i == len(segments) - 1:
                curr[segment] = val
            else:
                if segment not in curr or curr[segment] is None:
                    curr[segment] = {}
                curr = curr[segment]

    return nested

# %%
colab_project = client.get_project_by_id("68a8661d599246127d859169")

r = colab_project.get_results()['results']
flatten_object(r)
# Out:
# [{'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'day',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'daily number of records',
#   'paper experiments mobility_metric processing_step name': 'count',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent time distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent time',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent distance distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent distance',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'maximum likelihood fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'full_trajectory',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'radius of gyration',
#   'paper experiments mobility_metric processing_step name': 'compute gyration radius',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'power-law fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Xi\'an")',
#   'paper data_sample filters filter_key': 'city',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'compute speed distribution',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'day',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'daily number of records',
#   'paper experiments mobility_metric processing_step name': 'count',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent time distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent time',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent distance distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent distance',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'maximum likelihood fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'full_trajectory',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'radius of gyration',
#   'paper experiments mobility_metric processing_step name': 'compute gyration radius',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'power-law fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","1 week")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper data_sample completeness_statistic completeness_statistic_name': 'sampling rate',
#   'paper data_sample completeness_statistic completeness_statistic_value': 'mean,188s',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'compute speed distribution',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'day',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'daily number of records',
#   'paper experiments mobility_metric processing_step name': 'count',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent time distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent time',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent distance distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent distance',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'maximum likelihood fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'full_trajectory',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'radius of gyration',
#   'paper experiments mobility_metric processing_step name': 'compute gyration radius',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'waiting time',
#   'paper experiments mobility_metric processing_step name': 'power-law fitting',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'geographical',
#   'paper data_sample filters filter_expression': '("city","==","Shenyang")',
#   'paper data_sample filters filter_key': 'city',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'moving speed',
#   'paper experiments mobility_metric processing_step name': 'compute speed distribution',
#   'paper experiments mobility_metric processing_step type': 'model fitting',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","5 weeks")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'day',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'daily number of records',
#   'paper experiments mobility_metric processing_step name': 'count',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","5 weeks")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent time distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent time',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","5 weeks")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper experiments domain': 'data validation',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Comparison of MFR and CDR data sets to validate MFR as a finer-grained proxy for human mobility by analyzing distributions of daily records, interevent times, and interevent distances.',
#   'paper experiments mobility_metric temporal_aggregation': 'event',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'interevent distance distribution',
#   'paper experiments mobility_metric processing_step name': 'compute interevent distance',
#   'paper experiments mobility_metric processing_step type': 'noise removal',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","5 weeks")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
#   'paper experiments mobility_metric processing_step name': 'resampling',
#   'paper experiments mobility_metric processing_step type': 'aggregation',
#   'created_at': '2025-09-08 14:44:00',
#   '_version': 5,
#   '_is_latest': True,
#   '_result_id': '68beebb02f80a4e82c86e28a',
#   '_paper_id': '68b60f5e2f80a4e82c86e283'},
#  {'paper title': 'Temporal understanding of human mobility: A multi-time scale analysis',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'carrier',
#   'paper data_sample filters filter_type': 'temporal',
#   'paper data_sample filters filter_expression': '("duration","==","5 weeks")',
#   'paper data_sample filters filter_key': 'duration',
#   'paper experiments domain': 'model fitting',
#   'paper experiments code_location': '',
#   'paper experiments description': 'Multi-time scale analysis of human mobility metrics—displacement, radius of gyration, waiting time, and moving speed—using MFR under sampling intervals from 7.5min to 32h, fitting power-law/truncated power-law models and investigating parameter variation.',
#   'paper experiments mobility_metric temporal_aggregation': 'sampling_interval',
#   'paper experiments mobility_metric spatial_aggregation': 'cell_tower',
#   'paper experiments mobility_metric metric_name': 'displacement',
# ...
#   'paper experiments mobility_metric temporal_aggregation': 'per user',
#   'paper experiments mobility_metric spatial_aggregation': 'container level',
#   'paper experiments mobility_metric metric_name': 'container size correlation',
#   'paper experiments mobility_metric processing_step name': 'Spearman correlation',
#   'paper experiments mobility_metric processing_step type': 'data validation',
#   'created_at': '2025-09-08 15:32:58',
#   '_version': 2,
#   '_is_latest': True,
#   '_result_id': '68bef72a2f80a4e82c86e28b',
#   '_paper_id': '68a8bff82f80a4e82c86e27b'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'data generation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/',
#   'paper experiments description': 'Generation of synthetic human mobility dataset using an agent-based model including synthetic city, EPR mobility diary, Brownian motion micro-dynamics, and self-exciting point process for sparse trajectory sampling.',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'self-exciting point process',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'Gaussian spatial noise',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'DBScan',
#   'paper experiments mobility_metric processing_step type': 'stop detection',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Brownian motion micro-dynamics',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Gaussian spatial noise',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'mobility',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Project Lachesis',
#   'paper experiments mobility_metric processing_step type': 'stop detection',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'data generation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/',
#   'paper experiments description': 'Generation of synthetic human mobility dataset using an agent-based model including synthetic city, EPR mobility diary, Brownian motion micro-dynamics, and self-exciting point process for sparse trajectory sampling.',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'self-exciting point process',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'Gaussian spatial noise',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Testing robustness of DBScan stop detection algorithm on synthetic sparse trajectories with varying local sparsity patterns but fixed global sampling rate.',
#   'paper experiments mobility_metric temporal_aggregation': 'trip-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'visits to POI',
#   'paper experiments mobility_metric processing_step name': 'DBScan',
#   'paper experiments mobility_metric processing_step type': 'stop detection',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Brownian motion micro-dynamics',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Gaussian spatial noise',
#   'paper experiments mobility_metric processing_step type': 'filtering',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'},
#  {'paper title': 'Garden city: A synthetic dataset and sandbox environment for analysis of pre-processing algorithms for GPS human mobility data',
#   'paper data_sample dataset_type': 'geometry',
#   'paper data_sample provider_name': 'direct collection',
#   'paper experiments domain': 'algorithm validation',
#   'paper experiments code_location': 'https://github.com/Watts-Lab/nomad/tree/main/examples/garden-city',
#   'paper experiments description': 'Examining effect of movement variance and GPS noise on stop detection using Project Lachesis algorithm on synthetic park visits.',
#   'paper experiments mobility_metric temporal_aggregation': 'session-level',
#   'paper experiments mobility_metric spatial_aggregation': 'building-level',
#   'paper experiments mobility_metric metric_name': 'stop duration',
#   'paper experiments mobility_metric processing_step name': 'Project Lachesis',
#   'paper experiments mobility_metric processing_step type': 'stop detection',
#   'created_at': '2025-09-19 18:24:23',
#   '_version': 1,
#   '_is_latest': True,
#   '_result_id': '68cd9fd72f80a4e82c86e28d',
#   '_paper_id': '68cd9fd72f80a4e82c86e28c'}]

# %%
# Create a new feature
new_feature = FeatureCreate(
    feature_name="Study Duration",
    feature_description="Duration of the study in months",
    feature_identifier="study_duration",
    feature_type="integer",
)

created = client.create_feature(new_feature)
print(f"Created: {created.feature_name}")
print(f"   ID: {created.id}")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# /tmp/ipython-input-122382334.py in <cell line: 0>()
#       7 )
#       8
# ----> 9 created = client.create_feature(new_feature)
#      10 print(f"✅ Created: {created.feature_name}")
#      11 print(f"   ID: {created.id}")
#
# /usr/local/lib/python3.12/dist-packages/wattslab_atlas/client.py in create_feature(self, feature)
#     173             >>> created = client.create_feature(feature)
#     174         """
# --> 175         response = self._request("POST", "/features", json=feature.model_dump())
#     176         data = response.json()
#     177         return Feature(**data["feature"])
#
# /usr/local/lib/python3.12/dist-packages/wattslab_atlas/client.py in _request(self, method, endpoint, **kwargs)
#     125             raise ResourceNotFoundError(f"Resource not found: {endpoint}")
#     126         elif response.status_code >= 400:
# --> 127             raise APIError(f"API error: {response.text}", response.status_code)
#     128
#     129         return response
#
# APIError: API error: {"error":"2 validation errors for FeatureCreate\nfeature_type\n  Input should be 'text', 'number', 'boolean', 'enum' or 'parent' [type=literal_error, input_value='integer', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.11/v/literal_error\nfeature_prompt\n  Field required [type=missing, input_value={'feature_name': 'Study D... [], 'is_shared': False}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.11/v/missing"}
