# %%
# %pip uninstall nomad -y
# %pip install git+https://github.com/Watts-Lab/nomad.git@filtering#egg=nomad

# %%
import pandas as pd
import pytest
import pyarrow.parquet as pq
import pyarrow.fs as fs
import pyarrow.dataset as ds
import s3fs as fs3
import pyarrow as pa
from shapely.geometry import Polygon

from nomad.filters import to_projection, filter_to_polygon, _in_geo
import nomad.constants as constants

import sys
import os
import warnings
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../tests")))

# %%
# !pytest filter_tests.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.13.0, pytest-8.3.4, pluggy-1.5.0
# rootdir: /Users/thomasli/Documents/nomad
# configfile: pyproject.toml
# collected 21 items
#
# filter_tests.py .....................                                    [100%]
#
# =============================== warnings summary ===============================
# nomad/tests/filter_tests.py::test_filter_to_polygon_within_time_frame
# nomad/tests/filter_tests.py::test_filter_to_polygon_within_time_frame_multi_user
# nomad/tests/filter_tests.py::test_filter_to_polygon_outside_time_frame_multi_user
#   /Users/thomasli/Documents/nomad/nomad/filters.py:239: SettingWithCopyWarning:
#   A value is trying to be set on a copy of a slice from a DataFrame.
#   Try using .loc[row_indexer,col_indexer] = value instead
#
#   See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     traj_filtered[traj_cols['timestamp']] = pd.to_datetime(traj_filtered[traj_cols['timestamp']])
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 21 passed, 3 warnings in 3.53s ========================
