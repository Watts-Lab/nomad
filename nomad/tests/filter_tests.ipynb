# %%
# %pip install git+https://github.com/Watts-Lab/nomad.git@filtering#egg=nomad

# %%
import sys
import os
import warnings
import pandas as pd
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../tests")))

# %%
import pytest
import pyarrow.parquet as pq
import pyarrow.fs as fs
import pyarrow.dataset as ds
import s3fs as fs3
import pyarrow as pa
from shapely.geometry import Polygon

# %%
from nomad.filters import to_projection, filter_to_polygon, _in_geo
import nomad.constants as constants

# %%
# !pytest filter_tests.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.13.0, pytest-8.3.4, pluggy-1.5.0
# rootdir: /Users/thomasli/Documents/nomad
# configfile: pyproject.toml
# collected 21 items
#
# filter_tests.py .FF..FF..F....F......                                    [100%]
#
# =================================== FAILURES ===================================
# _____________________ test_projection_with_custom_columns ______________________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_projection_with_custom_columns(simple_df_one_user):
#         df_custom = simple_df_one_user.rename(columns={'longitude': 'lon', 'latitude': 'lat'})
# >       result = to_projection(traj=df_custom, longitude='lon', latitude='lat')
#
# filter_tests.py:74:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:80: in to_projection
#     traj_cols = loader._update_schema(traj_cols, kwargs)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {}, new_labels = {'latitude': 'lat', 'longitude': 'lon'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# ________________________ test_projection_with_traj_cols ________________________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_projection_with_traj_cols(simple_df_one_user):
#         df_custom = simple_df_one_user.rename(columns={'longitude': 'lon', 'latitude': 'lat'})
#         traj_cols = {'longitude': 'lon', 'latitude': 'lat'}
# >       result = to_projection(traj=df_custom, traj_cols=traj_cols, to_x='x_proj', to_y='y_proj')
#
# filter_tests.py:82:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:81: in to_projection
#     traj_cols = loader._update_schema(constants.DEFAULT_SCHEMA, traj_cols)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {'datetime': 'datetime', 'geohash': 'geohash', 'latitude': 'latitude', 'longitude': 'longitude', ...}
# new_labels = {'latitude': 'lat', 'longitude': 'lon'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# _____________________ test_filter_to_polygon_within_bounds _____________________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_filter_to_polygon_within_bounds(simple_df_one_user):
#         polygon = Polygon([(116.3190, 39.9840), (116.3200, 39.9840), (116.3200, 39.9850), (116.3190, 39.9850)])
# >       result = filter_to_polygon(simple_df_one_user, polygon,
#                                    T0='2008-10-23 00:00:00', T1='2008-10-24 00:00:00', k=1,
#                                    crs='EPSG:4326', longitude='longitude', latitude='latitude')
#
# filter_tests.py:104:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:200: in filter_to_polygon
#     traj_cols = loader._update_schema(traj_cols, kwargs)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {}, new_labels = {'latitude': 'latitude', 'longitude': 'longitude'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# ____________________ test_filter_to_polygon_outside_bounds _____________________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_filter_to_polygon_outside_bounds(simple_df_one_user):
#         polygon = Polygon([(116.3180, 39.9830), (116.3185, 39.9830), (116.3185, 39.9835), (116.3180, 39.9835)])
# >       result = filter_to_polygon(simple_df_one_user, polygon,
#                                    T0='2008-10-23 00:00:00', T1='2008-10-24 00:00:00', k=1,
#                                    crs='EPSG:4326', longitude='longitude', latitude='latitude')
#
# filter_tests.py:111:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:200: in filter_to_polygon
#     traj_cols = loader._update_schema(traj_cols, kwargs)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {}, new_labels = {'latitude': 'latitude', 'longitude': 'longitude'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# __________________ test_filter_to_polygon_with_custom_columns __________________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_filter_to_polygon_with_custom_columns(simple_df_one_user):
#         df_custom = simple_df_one_user.rename(columns={'longitude': 'lon', 'latitude': 'lat'})
#         polygon = Polygon([(116.3190, 39.9840), (116.3200, 39.9840), (116.3200, 39.9850), (116.3190, 39.9850)])
# >       result = filter_to_polygon(df_custom, polygon,
#                                    T0='2008-10-23 00:00:00', T1='2008-10-24 00:00:00',  k=1,
#                                    crs='EPSG:4326', longitude='lon', latitude='lat')
#
# filter_tests.py:138:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:200: in filter_to_polygon
#     traj_cols = loader._update_schema(traj_cols, kwargs)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {}, new_labels = {'latitude': 'lat', 'longitude': 'lon'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# _______________ test_projection_and_filter_to_polygon_wrong_cols _______________
#
# simple_df_one_user =    user_id   latitude   longitude            timestamp
# 0        1  39.984094  116.319236  2008-10-23 13:53:05
# 1       ... 13:53:06
# 2        1  39.984224  116.319402  2008-10-23 13:53:11
# 3        1  39.984211  116.319389  2008-10-23 13:53:16
#
#     def test_projection_and_filter_to_polygon_wrong_cols(simple_df_one_user):
#         projected_df = to_projection(traj=simple_df_one_user)
#         polygon = Polygon([(1.294861e+07, 4.863647e+06), (1.294861e+07, 4.863649e+06),
#                            (1.294863e+07, 4.863649e+06), (1.294863e+07, 4.863647e+06)])
# >       result = filter_to_polygon(projected_df, polygon,
#                                    T0='2008-10-23 00:00:00', T1='2008-10-24 00:00:00', k=1,
#                                    longitude='longitude', latitude='latitude')
#
# filter_tests.py:175:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ../filters.py:200: in filter_to_polygon
#     traj_cols = loader._update_schema(traj_cols, kwargs)
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# original = {}, new_labels = {'latitude': 'latitude', 'longitude': 'longitude'}
#
#     def _update_schema(original, new_labels):
#
#         updated_schema = dict(original)
#         for label in new_labels:
# >           if label in constants.DEFAULT_SCHEMA:
# E           NameError: name 'constants' is not defined
#
# ../daphmeIO.py:19: NameError
# =============================== warnings summary ===============================
# nomad/tests/filter_tests.py::test_filter_to_polygon_within_time_frame
# nomad/tests/filter_tests.py::test_filter_to_polygon_within_time_frame_multi_user
# nomad/tests/filter_tests.py::test_filter_to_polygon_outside_time_frame_multi_user
#   /Users/thomasli/Documents/nomad/nomad/filters.py:243: SettingWithCopyWarning:
#   A value is trying to be set on a copy of a slice from a DataFrame.
#   Try using .loc[row_indexer,col_indexer] = value instead
#
#   See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     traj_filtered[traj_cols['timestamp']] = pd.to_datetime(traj_filtered[traj_cols['timestamp']])
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED filter_tests.py::test_projection_with_custom_columns - NameError: name 'constants' is not defined
# FAILED filter_tests.py::test_projection_with_traj_cols - NameError: name 'constants' is not defined
# FAILED filter_tests.py::test_filter_to_polygon_within_bounds - NameError: name 'constants' is not defined
# FAILED filter_tests.py::test_filter_to_polygon_outside_bounds - NameError: name 'constants' is not defined
# FAILED filter_tests.py::test_filter_to_polygon_with_custom_columns - NameError: name 'constants' is not defined
# FAILED filter_tests.py::test_projection_and_filter_to_polygon_wrong_cols - NameError: name 'constants' is not defined
# =================== 6 failed, 15 passed, 3 warnings in 4.14s ===================
